# %% [markdown]
# ---
# title: "My Presentation"
# author: "Your Name"
# format:
#   revealjs:
#     slide-number: true
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Introduction
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#
# - Point one
# - Point two
# - Point three

# %% [markdown]
# ## Background
#
# ![First image](../images/mountain.jpg)
#
# This idea builds on prior work [@jordan2015machine].

# %% [markdown]
# ## Supporting Work
#
# ![Second image](../images/trees.jpg)
#
# Further discussion is found in @akmalia2025expression.

# %% [markdown]
# ## Data Visualization

# %%
#| code-fold: true
#| code-summary: "Show code"

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.plot(x, y)
plt.title("Cosine Wave")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.show()
